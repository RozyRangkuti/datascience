# %% [markdown]
# <a href="https://colab.research.google.com/github/RozyRangkuti/datascience/blob/main/customer_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('/content/drive/MyDrive/data1/segmentation data.csv')
df
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2000 non-null   int64
#  1   Sex              2000 non-null   int64
#  2   Marital status   2000 non-null   int64
#  3   Age              2000 non-null   int64
#  4   Education        2000 non-null   int64
#  5   Income           2000 non-null   int64
#  6   Occupation       2000 non-null   int64
#  7   Settlement size  2000 non-null   int64
# dtypes: int64(8)
# memory usage: 125.1 KB

# %%
df.isna().sum()
# Out:
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %%
df.nunique()
# Out:
# ID                 2000
# Sex                   2
# Marital status        2
# Age                  58
# Education             4
# Income             1982
# Occupation            3
# Settlement size       3
# dtype: int64

# %%
# Melihat jumlah data duplikat
rows_before = len(df)
df.drop_duplicates(inplace = True)
rows_after = len(df)

print(f"Jumlah baris yang terdapat duplikasi: {rows_before - rows_after}")
# Out:
# Jumlah baris yang terdapat duplikasi: 0

# %%
df.dtypes
# Out:
# ID                 int64
# Sex                int64
# Marital status     int64
# Age                int64
# Education          int64
# Income             int64
# Occupation         int64
# Settlement size    int64
# dtype: object

# %%
df.describe()
# Out:
#                  ID          Sex  Marital status          Age   Education  \
# count  2.000000e+03  2000.000000     2000.000000  2000.000000  2000.00000
# mean   1.000010e+08     0.457000        0.496500    35.909000     1.03800
# std    5.774946e+02     0.498272        0.500113    11.719402     0.59978
# min    1.000000e+08     0.000000        0.000000    18.000000     0.00000
# 25%    1.000005e+08     0.000000        0.000000    27.000000     1.00000
# 50%    1.000010e+08     0.000000        0.000000    33.000000     1.00000
# 75%    1.000015e+08     1.000000        1.000000    42.000000     1.00000
# max    1.000020e+08     1.000000        1.000000    76.000000     3.00000
#
#               Income   Occupation  Settlement size
# count    2000.000000  2000.000000      2000.000000
# mean   120954.419000     0.810500         0.739000
# std     38108.824679     0.638587         0.812533
# min     35832.000000     0.000000         0.000000
# ...

# %%
# Mengubah nama variabel
col_names_cleaned = []

for col_name in df.columns:
  col_names_cleaned.append(col_name.lower().replace(" ", "_"))

df.columns = col_names_cleaned

df.head()
# Out:
#           id  sex  marital_status  age  education  income  occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    settlement_size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
labels = df['sex'].replace({0:'laki-laki', 1:'Perempuan'}).value_counts().index
size = df['sex'].replace({0:'laki-laki', 1:'Perempuan'}).value_counts()

# %%
labels
# Out:
# Index(['laki-laki', 'Perempuan'], dtype='object', name='sex')

# %%
size
# Out:
# sex
# laki-laki    1086
# Perempuan     914
# Name: count, dtype: int64

# %%
fig = px.pie(names=labels, values=size, color_discrete_sequence=["lightblue", "pink"])
fig.update_traces(textposition='inside', textinfo='percent+label+value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x='age', nbins=100, title='Persebaran Data Berdasarkan Umur Pelanggan')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
labels_ms = df['marital_status'].replace({0:'single', 1:'non-single'}).value_counts().index
size_ms = df['marital_status'].replace({0:'single', 1:'non-single'}).value_counts()

# %%
labels_ms
# Out:
# Index(['single', 'non-single'], dtype='object', name='marital_status')

# %%
size_ms
# Out:
# marital_status
# single        1007
# non-single     993
# Name: count, dtype: int64

# %%
fig = px.pie(names=labels_ms, values=size_ms, color_discrete_sequence=["red", "blue"])
fig.update_traces(textposition='inside', textinfo='percent+label+value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
labels_edu = df['education'].replace({0:'other/unknown', 1:'high school', 2:'university', 3:'graduate school'}).value_counts().index
size_edu = df['education'].replace({0:'other/unknown', 1:'high school', 2:'university', 3:'graduate school'}).value_counts()

# %%
labels_edu
# Out:
# Index(['high school', 'university', 'other/unknown', 'graduate school'], dtype='object', name='education')

# %%
size_edu
# Out:
# education
# high school        1386
# university          291
# other/unknown       287
# graduate school      36
# Name: count, dtype: int64

# %%
fig = px.pie(names=labels_edu, values=size_edu, color_discrete_sequence=["red", "blue", "green", "yellow"])
fig.update_traces(textposition='inside', textinfo='percent+label+value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x='income', nbins=100, title='Persebaran Data Berdasarkan income Pelanggan')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
labels_occ = df['occupation'].replace({0:'unemployed / unskilled', 1:'skilled employee / official', 2:'management / self-employed / highly qualified employee / officer'}).value_counts().index
size_occ = df['occupation'].replace({0:'unemployed / unskilled', 1:'skilled employee / official', 2:'management / self-employed / highly qualified employee / officer'}).value_counts()

# %%
labels_occ
# Out:
# Index(['skilled employee / official', 'unemployed / unskilled',
#        'management / self-employed / highly qualified employee / officer'],
#       dtype='object', name='occupation')

# %%
size_occ
# Out:
# occupation
# skilled employee / official                                         1113
# unemployed / unskilled                                               633
# management / self-employed / highly qualified employee / officer     254
# Name: count, dtype: int64

# %%
fig = px.pie(names=labels_occ, values=size_occ, color_discrete_sequence=["red", "blue", "green"])
fig.update_traces(textposition='inside', textinfo='percent+label+value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pred_data = df.drop(['id'], axis = 1)
pred_data
# Out:
#       sex  marital_status  age  education  income  occupation  settlement_size
# 0       0               0   67          2  124670           1                2
# 1       1               1   22          1  150773           1                2
# 2       0               0   49          1   89210           0                0
# 3       0               0   45          1  171565           1                1
# 4       0               0   53          1  149031           1                1
# ...   ...             ...  ...        ...     ...         ...              ...
# 1995    1               0   47          1  123525           0                0
# 1996    1               1   27          1  117744           1                0
# 1997    0               0   31          0   86400           0                0
# 1998    1               1   24          1   97968           0                0
# 1999    0               0   25          0   68416           0                0
#
# [2000 rows x 7 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
col_names = pred_data.columns
X = scaler.fit_transform(pred_data)
X = pd.DataFrame(data=X, columns=col_names)
X.describe()
# Out:
#                sex  marital_status          age    education       income  \
# count  2000.000000     2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.457000        0.496500     0.308776     0.346000     0.311197
# std       0.498272        0.500113     0.202059     0.199927     0.139321
# min       0.000000        0.000000     0.000000     0.000000     0.000000
# 25%       0.000000        0.000000     0.155172     0.333333     0.226048
# 50%       0.000000        0.000000     0.258621     0.333333     0.291434
# 75%       1.000000        1.000000     0.413793     0.333333     0.373778
# max       1.000000        1.000000     1.000000     1.000000     1.000000
#
#         occupation  settlement_size
# count  2000.000000      2000.000000
# mean      0.405250         0.369500
# std       0.319294         0.406266
# min       0.000000         0.000000
# 25%       0.000000         0.000000
# 50%       0.500000         0.500000
# 75%       0.500000         0.500000
# ...

# %%
k_values = range(2, 12)
wcss = []

# %%
for k in k_values:
  kmeans = KMeans(n_clusters=k, random_state=0)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# ...

# %%
fig = px.line(x = k_values, y = wcss, title = 'Elbow Plot')
fig.update_layout(xaxis_title='Number of Clusters (k)', yaxis_title='Inertia')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Mereduksi Dimensional Data

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 3, random_state = 42)
X_pca = pca.fit_transform(X)

# %%
X_pca_df = pd.DataFrame(data=X_pca, columns=['X1', 'X2', 'X3'])

# %% [markdown]
# # Membuat Model Klasterisasi

# %%
kmeans = KMeans(n_clusters=6, random_state=0)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# KMeans(n_clusters=6, random_state=0)

# %%
labels = kmeans.labels_
X_pca_df['Labels'] = labels

# %%
X_pca_df.head()
# Out:
#          X1        X2        X3  Labels
# 0  0.826086  0.354652  0.158422       2
# 1 -0.524891  0.716293  0.240947       4
# 2  0.486009 -0.690668 -0.181594       5
# 3  0.707351 -0.028668  0.044773       2
# 4  0.712574 -0.037939  0.046813       2

# %%
# ubah tipe data menjadi string agar mempermudah dalam visualisasi
X_pca_df['Labels'] = X_pca_df['Labels'].astype(str)

# %%
fig = px.scatter_3d(X_pca_df, x='X1', y='X2', z='X3', color=X_pca_df['Labels'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['cluster'] = kmeans.labels_
df
# Out:
#              id  sex  marital_status  age  education  income  occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       settlement_size  cluster
# 0                   2        2
# ...

# %% [markdown]
# # Analisa Karakteristik Hasil Klasterisasi

# %%
# Jumlah data tiap klaster
df_cluster_n = df[['cluster', 'id']].groupby('cluster').count().sort_values('cluster').reset_index()
df_cluster_n
# Out:
#    cluster   id
# 0        0  257
# 1        1  430
# 2        2  516
# 3        3  178
# 4        4  306
# 5        5  313

# %%
# Visualisasi jumlah data tiap klaster
fig = px.bar(df_cluster_n, x='cluster', y='id', color='cluster', title='Perbandingan Jumlah Data Setiap Cluster', text_auto=True)
fig.update_traces(textfont_size=10, textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Perbandingan Jenis Kelamin Setiap Klaster

# %%
# Perbandingan Jenis Kelamin Setiap Klaster
clus_sex = df[['cluster', 'sex', 'id']].groupby(['cluster', 'sex']).count().sort_values(['cluster', 'sex']).reset_index()
clus_sex['sex'].replace({0:'laki-laki', 1:'Perempuan'}, inplace=True)
clus_sex
# Out:
#    cluster        sex   id
# 0        0  laki-laki  257
# 1        1  Perempuan  430
# 2        2  laki-laki  516
# 3        3  Perempuan  178
# 4        4  Perempuan  306
# 5        5  laki-laki  313

# %%
# Visualisasi perbandingan jenis kelamin tiap klaster
fig = px.bar(clus_sex, x='cluster', y='id', color='sex', title='Perbandingan Jenis Kelamin Setiap Cluster', text_auto=True)
fig.update_traces(textfont_size=10, textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Perbandingan Status Menikah Setiap Klaster

# %%
clus_marital = df[['cluster', 'marital_status', 'id']].groupby(['cluster', 'marital_status']).count().sort_values(['cluster', 'marital_status']).reset_index()
clus_marital['marital_status'].replace({0:'Belum Menikah', 1:'Pernah Menikah'}, inplace=True)
clus_marital
# Out:
#    cluster  marital_status   id
# 0        0  Pernah Menikah  257
# 1        1  Pernah Menikah  430
# 2        2   Belum Menikah  516
# 3        3   Belum Menikah  178
# 4        4  Pernah Menikah  306
# 5        5   Belum Menikah  313

# %%
# Visualisasi perbandingan status menikah tiap klaster
fig = px.bar(clus_marital, x='cluster', y='id', color='marital_status', title='Perbandingan Status Pernikahan Setiap Cluster', text_auto=True)
fig.update_traces(textfont_size=10, textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Perbandingan Persebaran Umur Setiap Klaster

# %%
fig = px.histogram(df, x='age', color='cluster', nbins=100, title = 'Persebaran Data berdasarkan Umur Pelanggan')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[['cluster', 'age']].groupby('cluster').mean().sort_values('cluster')
# Out:
#                age
# cluster
# 0        33.968872
# 1        32.416279
# 2        40.007752
# 3        35.146067
# 4        34.284314
# 5        37.565495

# %% [markdown]
# # Perbandingan Jenjang Pendidikan Setiap Klaster

# %%
clus_edu = df[['cluster', 'education', 'id']].groupby(['cluster', 'education']).count().sort_values(['cluster', 'education']).reset_index()
clus_edu['education'].replace({0:'other/unknown', 1:'high school', 2:'university', 3:'graduate school'}, inplace=True)
clus_edu
# Out:
#     cluster        education   id
# 0         0      high school  195
# 1         0       university   55
# 2         0  graduate school    7
# 3         1      high school  350
# 4         1       university   69
# 5         1  graduate school   11
# 6         2    other/unknown  151
# 7         2      high school  306
# 8         2       university   59
# 9         3    other/unknown   32
# 10        3      high school  128
# 11        3       university   16
# 12        3  graduate school    2
# 13        4      high school  220
# 14        4       university   70
# 15        4  graduate school   16
# 16        5    other/unknown  104
# 17        5      high school  187
# 18        5       university   22

# %%
# Visualisasi perbandingan Jenjang Pendidikan tiap klaster
fig = px.bar(clus_edu, x='cluster', y='id', color='education', title='Perbandingan Jenjang Pendidikan Setiap Cluster', barmode="group", text_auto=True)
fig.update_traces(textfont_size=10, textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Perbandingan Jenis Pekerjaan Setiap Klaster

# %%
clus_ocu = df[['cluster', 'occupation', 'id']].groupby(['cluster', 'occupation']).count().sort_values(['cluster', 'occupation']).reset_index()
clus_ocu['occupation'].replace({0:'Pengangguran', 1:'Karyawan', 2:'Level Manajemen'}, inplace=True)
clus_ocu
# Out:
#     cluster       occupation   id
# 0         0     Pengangguran   60
# 1         0         Karyawan  154
# 2         0  Level Manajemen   43
# 3         1     Pengangguran  246
# 4         1         Karyawan  184
# 5         2     Pengangguran   10
# 6         2         Karyawan  359
# 7         2  Level Manajemen  147
# 8         3     Pengangguran  114
# 9         3         Karyawan   62
# 10        3  Level Manajemen    2
# 11        4     Pengangguran    2
# 12        4         Karyawan  246
# 13        4  Level Manajemen   58
# 14        5     Pengangguran  201
# 15        5         Karyawan  108
# 16        5  Level Manajemen    4

# %%
# Visualisasi perbandingan Jenis Pekerjaan tiap klaster
fig = px.bar(clus_ocu, x='cluster', y='id', color='occupation', title='Perbandingan Jenis Pekerjaan Setiap Cluster', barmode="group", text_auto=True)
fig.update_traces(textfont_size=10, textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[['cluster', 'occupation']].groupby('cluster').mean().sort_values('occupation')
# Out:
#          occupation
# cluster
# 5          0.370607
# 3          0.370787
# 1          0.427907
# 0          0.933852
# 4          1.183007
# 2          1.265504

# %% [markdown]
# # Perbandingan jenis Kota Tinggal Setiap Klaster

# %%
clus_set = df[['cluster', 'settlement_size', 'id']].groupby(['cluster', 'settlement_size']).count().sort_values(['cluster', 'settlement_size']).reset_index()
clus_set['settlement_size'].replace({0:'Kota Kecil', 1:'Kota Menengah', 2:'kota Besar'}, inplace=True)
clus_set
# Out:
#     cluster settlement_size   id
# 0         0      Kota Kecil   99
# 1         0   Kota Menengah   80
# 2         0      kota Besar   78
# 3         1      Kota Kecil  425
# 4         1   Kota Menengah    5
# 5         2      Kota Kecil    1
# 6         2   Kota Menengah  239
# 7         2      kota Besar  276
# 8         3      Kota Kecil  165
# 9         3   Kota Menengah   13
# 10        4      Kota Kecil    5
# 11        4   Kota Menengah  188
# 12        4      kota Besar  113
# 13        5      Kota Kecil  294
# 14        5   Kota Menengah   19

# %%
# Visualisasi perbandingan Jenis Kota Tinggal tiap klaster
fig = px.bar(clus_set, x='cluster', y='id', color='settlement_size', title='Perbandingan Status Tempat Tinggal Setiap Cluster', barmode="group", text_auto=True)
fig.update_traces(textfont_size=10, textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Perbandingan Penghasilan Setiap Klaster

# %%
fig = px.histogram(df, x='income', color='cluster', nbins=100, title = 'Persebaran Data Incomoe Berdasarkan Cluster Pelanggan')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[['cluster', 'income']].groupby('cluster').mean().sort_values('income')
# Out:
#                 income
# cluster
# 3         97997.241573
# 1        102142.332558
# 5        102782.319489
# 0        122976.723735
# 4        136536.702614
# 2        145325.602713
